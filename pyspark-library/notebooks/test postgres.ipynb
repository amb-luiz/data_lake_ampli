# %%
import psycopg2

# %%
conn = psycopg2.connect(
                        host="somepostgres",
                        dbname="testintegration",
                        user="postgres",
                        password="awspass2"
                    )

# %%
cur = conn.cursor()
        
print('PostgreSQL database version:')
cur.execute('SELECT * from tb_rent')
db_version = cur.fetchall()
db_version
# Out:
# PostgreSQL database version:
# [('1',
#   '3540803609051089',
#   '2020-04-12',
#   '7:43:29',
#   'Ladies in Retirement',
#   'Drama'),
#  ('1',
#   '3540803609051089',
#   '2020-04-12',
#   '7:43:29',
#   'Ladies in Retirement',
#   'Drama'),
#  ('1',
#   '3540803609051089',
#   '2020-04-12',
#   '7:43:29',
#   'Ladies in Retirement',
#   'Drama'),
#  ('1',
#   '3540803609051089',
#   '2020-04-12',
#   '7:43:29',
#   'Ladies in Retirement',
#   'Drama'),
#  ('1',
#   '3540803609051089',
#   '2020-04-12',
#   '7:43:29',
#   'Ladies in Retirement',
#   'Drama'),
#  ('1',
#   '3540803609051089',
#   '2020-04-12',
#   '7:43:29',
#   'Ladies in Retirement',
#   'Drama'),
#  ('1',
#   '3540803609051089',
#   '2020-04-12',
#   '7:43:29',
#   'Ladies in Retirement',
#   'Drama'),
#  ('1',
#   '3540803609051089',
#   '2020-04-12',
#   '7:43:29',
#   'Ladies in Retirement',
#   'Drama'),
#  ('1',
#   '3540803609051089',
#   '2020-04-12',
#   '7:43:29',
#   'Ladies in Retirement',
# ...
