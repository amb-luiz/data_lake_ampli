# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://62f962911465:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.format('parquet').load('/spark-pyutil/data/output/datamask')
df.show()
# Out:
# +---+----------+---------+--------------------+------+-------------------+--------------------+
# | id| date_rent|time_rent|        movie_genres|offset|        credit_card|               movie|
# +---+----------+---------+--------------------+------+-------------------+--------------------+
# |724|2020-04-12| 13:30:57|        Comedy|Drama|     2|    757609929565136|  AL2Ap~9HcO!dLMN3BQ|
# |108|2020-04-13|  4:27:52|               Drama|     2|   5299517041169988|       mwEQA[2Y^0qj"|
# |280|2020-04-12|  4:32:28|           Drama|War|     2|   9346532445013620|.s\:3R`:[@hVs?|M4...|
# |370|2020-04-13|  0:00:10|      Drama|Thriller|     2|   3425019127545463|               &U!5r|
# |349|2020-04-12|  7:15:37|Crime|Drama|Fanta...|     2|5739584877780503668|           {"(d}7*B0|
# |689|2020-04-13| 22:38:50|            Thriller|     2|   2381092336778167|               'o6dN|
# |397|2020-04-13| 17:14:38|                null|     2|   8213601009317690|           [%MC`4eX[|
# ...

# %%
! ls '/spark-pyutil/data/output/datamask'
# Out:
#  _SUCCESS  'offset=1'
