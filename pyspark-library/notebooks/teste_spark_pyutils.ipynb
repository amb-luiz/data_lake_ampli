# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://62f962911465:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from spark_pyutil import pyspark

# %%
pyspark.main([
                "--job-name","TestRentDataMask",
                "--execution-datetime","2",
                "--config-path","/spark-pyutil/test/test_parms/test_parms.json"])
# Out:
# Exception FTE Encrypt: non-alphabet character: 'á'
# Exception FTE Encrypt: non-alphabet character: 'ã'
# Exception FTE Encrypt: non-alphabet character: 'é'
# Exception FTE Encrypt: non-alphabet character: 'ô'
# Exception FTE Encrypt: non-alphabet character: 'è'
# Exception FTE Encrypt: non-alphabet character: 'ô'
# Exception FTE Encrypt: non-alphabet character: 'ô'
# Exception FTE Encrypt: non-alphabet character: 'ä'
# Exception FTE Encrypt: non-alphabet character: 'û'
# Exception FTE Encrypt: non-alphabet character: 'á'
# Exception FTE Encrypt: non-alphabet character: 'ü'
# Exception FTE Encrypt: non-alphabet character: 'û'
# Exception FTE Encrypt: non-alphabet character: 'í'
# Exception FTE Encrypt: non-alphabet character: 'ó'
# Exception FTE Encrypt: non-alphabet character: 'é'
# Exception FTE Encrypt: non-alphabet character: 'û'
# Exception FTE Encrypt: non-alphabet character: 'é'
# Exception FTE Encrypt: non-alphabet character: 'ê'
# ...

# %%
! ls /spark-pyutil/data/output/datamask/
# Out:
# _SUCCESS
# part-00000-24dfba39-cc83-47c9-bc85-9288ce6434bc-c000.snappy.parquet
# part-00001-24dfba39-cc83-47c9-bc85-9288ce6434bc-c000.snappy.parquet
# part-00002-24dfba39-cc83-47c9-bc85-9288ce6434bc-c000.snappy.parquet
# part-00003-24dfba39-cc83-47c9-bc85-9288ce6434bc-c000.snappy.parquet
# part-00004-24dfba39-cc83-47c9-bc85-9288ce6434bc-c000.snappy.parquet
